# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\108pa\anaconda3\envs\py310\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\108pa\anaconda3\envs\py310\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\108pa\anaconda3\envs\py310\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\108pa\anaconda3\envs\py310\lib\site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in c:\users\108pa\anaconda3\envs\py310\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\108pa\anaconda3\envs\py310\lib\site-packages (from click->nltk) (0.4.6)

# %%
from gensim.models import Word2Vec
import gensim
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
import warnings

warnings.filterwarnings(action='ignore')

# %%
# Download required NLTK data
try:
    nltk.data.find('tokenizers/punkt')
    print("Punkt tokenizer already downloaded")
except LookupError:
    print("Downloading Punkt tokenizer...")
    nltk.download('punkt', quiet=False)
    print("Download complete!")

# Also download punkt_tab if needed (sometimes required for newer NLTK versions)
try:
    nltk.data.find('tokenizers/punkt_tab')
    print("Punkt_tab tokenizer already downloaded")
except LookupError:
    print("Downloading Punkt_tab tokenizer...")
    nltk.download('punkt_tab', quiet=False)
    print("Download complete!")
# Out:
# Punkt tokenizer already downloaded
# Downloading Punkt_tab tokenizer...
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\108pa\AppData\Roaming\nltk_data...
# Download complete!
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
import zipfile

with zipfile.ZipFile("./data/Gutenburg.zip", 'r') as zip_ref:
    file_name = zip_ref.namelist()[0]
    with zip_ref.open(file_name) as file:
        content = file.read().decode('utf-8', errors='ignore')
        cleaned_text = content.replace("\n", " ")
        print("File loaded")
# Out:
# File loaded

# %%
sent_tokenize(cleaned_text)
# Out:
# ['*** START OF THE PROJECT GUTENBERG EBOOK 11 ***\r \r [Illustration]\r \r \r \r \r Alice’s Adventures in Wonderland\r \r by Lewis Carroll\r \r THE MILLENNIUM FULCRUM EDITION 3.0\r \r Contents\r \r  CHAPTER I.',
#  'Down the Rabbit-Hole\r  CHAPTER II.',
#  'The Pool of Tears\r  CHAPTER III.',
#  'A Caucus-Race and a Long Tale\r  CHAPTER IV.',
#  'The Rabbit Sends in a Little Bill\r  CHAPTER V.     Advice from a Caterpillar\r  CHAPTER VI.',
#  'Pig and Pepper\r  CHAPTER VII.',
#  'A Mad Tea-Party\r  CHAPTER VIII.',
#  'The Queen’s Croquet-Ground\r  CHAPTER IX.',
#  'The Mock Turtle’s Story\r  CHAPTER X.',
#  'The Lobster Quadrille\r  CHAPTER XI.',
#  'Who Stole the Tarts?',
#  'CHAPTER XII.',
#  'Alice’s Evidence\r \r \r \r \r CHAPTER I.',
#  'Down the Rabbit-Hole\r \r \r Alice was beginning to get very tired of sitting by her sister on the\r bank, and of having nothing to do: once or twice she had peeped into\r the book her sister was reading, but it had no pictures or\r conversations in it, “and what is the use of a book,” thought Alice\r “without pictures or conversations?”\r \r So she was considering in her own mind (as well as she could, for the\r hot day made her feel very sleepy and stupid), whether the pleasure of\r making a daisy-chain would be worth the trouble of getting up and\r picking the daisies, when suddenly a White Rabbit with pink eyes ran\r close by her.',
#  'There was nothing so _very_ remarkable in that; nor did Alice think it\r so _very_ much out of the way to hear the Rabbit say to itself, “Oh\r dear!',
#  'Oh dear!',
#  'I shall be late!” (when she thought it over afterwards,\r it occurred to her that she ought to have wondered at this, but at the\r time it all seemed quite natural); but when the Rabbit actually _took a\r watch out of its waistcoat-pocket_, and looked at it, and then hurried\r on, Alice started to her feet, for it flashed across her mind that she\r had never before seen a rabbit with either a waistcoat-pocket, or a\r watch to take out of it, and burning with curiosity, she ran across the\r field after it, and fortunately was just in time to see it pop down a\r large rabbit-hole under the hedge.',
#  'In another moment down went Alice after it, never once considering how\r in the world she was to get out again.',
#  'The rabbit-hole went straight on like a tunnel for some way, and then\r dipped suddenly down, so suddenly that Alice had not a moment to think\r about stopping herself before she found herself falling down a very\r deep well.',
#  'Either the well was very deep, or she fell very slowly, for she had\r plenty of time as she went down to look about her and to wonder what\r was going to happen next.',
#  'First, she tried to look down and make out\r what she was coming to, but it was too dark to see anything; then she\r looked at the sides of the well, and noticed that they were filled with\r cupboards and book-shelves; here and there she saw maps and pictures\r hung upon pegs.',
#  'She took down a jar from one of the shelves as she\r passed; it was labelled “ORANGE MARMALADE”, but to her great\r disappointment it was empty: she did not like to drop the jar for fear\r of killing somebody underneath, so managed to put it into one of the\r cupboards as she fell past it.',
#  '“Well!” thought Alice to herself, “after such a fall as this, I shall\r think nothing of tumbling down stairs!',
#  'How brave they’ll all think me\r at home!',
#  'Why, I wouldn’t say anything about it, even if I fell off the\r top of the house!” (Which was very likely true.)',
#  'Down, down, down.',
#  'Would the fall _never_ come to an end?',
#  '“I wonder how\r many miles I’ve fallen by this time?” she said aloud.',
#  '“I must be\r getting somewhere near the centre of the earth.',
#  'Let me see: that would\r be four thousand miles down, I think—” (for, you see, Alice had learnt\r several things of this sort in her lessons in the schoolroom, and\r though this was not a _very_ good opportunity for showing off her\r knowledge, as there was no one to listen to her, still it was good\r practice to say it over) “—yes, that’s about the right distance—but\r then I wonder what Latitude or Longitude I’ve got to?” (Alice had no\r idea what Latitude was, or Longitude either, but thought they were nice\r grand words to say.)',
#  'Presently she began again.',
#  '“I wonder if I shall fall right _through_\r the earth!',
#  'How funny it’ll seem to come out among the people that walk\r with their heads downward!',
#  'The Antipathies, I think—” (she was rather\r glad there _was_ no one listening, this time, as it didn’t sound at all\r the right word) “—but I shall have to ask them what the name of the\r country is, you know.',
#  'Please, Ma’am, is this New Zealand or Australia?”\r (and she tried to curtsey as she spoke—fancy _curtseying_ as you’re\r falling through the air!',
#  'Do you think you could manage it?)',
#  '“And what\r an ignorant little girl she’ll think me for asking!',
#  'No, it’ll never do\r to ask: perhaps I shall see it written up somewhere.”\r \r Down, down, down.',
#  'There was nothing else to do, so Alice soon began\r talking again.',
#  '“Dinah’ll miss me very much to-night, I should think!”\r (Dinah was the cat.)',
#  '“I hope they’ll remember her saucer of milk at\r tea-time.',
#  'Dinah my dear!',
#  'I wish you were down here with me!',
#  'There are\r no mice in the air, I’m afraid, but you might catch a bat, and that’s\r very like a mouse, you know.',
#  'But do cats eat bats, I wonder?” And here\r Alice began to get rather sleepy, and went on saying to herself, in a\r dreamy sort of way, “Do cats eat bats?',
#  'Do cats eat bats?” and\r sometimes, “Do bats eat cats?” for, you see, as she couldn’t answer\r either question, it didn’t much matter which way she put it.',
#  'She felt\r that she was dozing off, and had just begun to dream that she was\r walking hand in hand with Dinah, and saying to her very earnestly,\r “Now, Dinah, tell me the truth: did you ever eat a bat?” when suddenly,\r thump!',
#  'thump!',
#  'down she came upon a heap of sticks and dry leaves, and\r the fall was over.',
#  'Alice was not a bit hurt, and she jumped up on to her feet in a moment:\r she looked up, but it was all dark overhead; before her was another\r long passage, and the White Rabbit was still in sight, hurrying down\r it.',
#  'There was not a moment to be lost: away went Alice like the wind,\r and was just in time to hear it say, as it turned a corner, “Oh my ears\r and whiskers, how late it’s getting!” She was close behind it when she\r turned the corner, but the Rabbit was no longer to be seen: she found\r herself in a long, low hall, which was lit up by a row of lamps hanging\r from the roof.',
#  'There were doors all round the hall, but they were all locked; and when\r Alice had been all the way down one side and up the other, trying every\r door, she walked sadly down the middle, wondering how she was ever to\r get out again.',
#  'Suddenly she came upon a little three-legged table, all made of solid\r glass; there was nothing on it except a tiny golden key, and Alice’s\r first thought was that it might belong to one of the doors of the hall;\r but, alas!',
#  'either the locks were too large, or the key was too small,\r but at any rate it would not open any of them.',
#  'However, on the second\r time round, she came upon a low curtain she had not noticed before, and\r behind it was a little door about fifteen inches high: she tried the\r little golden key in the lock, and to her great delight it fitted!',
#  'Alice opened the door and found that it led into a small passage, not\r much larger than a rat-hole: she knelt down and looked along the\r passage into the loveliest garden you ever saw.',
#  'How she longed to get\r out of that dark hall, and wander about among those beds of bright\r flowers and those cool fountains, but she could not even get her head\r through the doorway; “and even if my head would go through,” thought\r poor Alice, “it would be of very little use without my shoulders.',
#  'Oh,\r how I wish I could shut up like a telescope!',
#  'I think I could, if I only\r knew how to begin.” For, you see, so many out-of-the-way things had\r happened lately, that Alice had begun to think that very few things\r indeed were really impossible.',
#  'There seemed to be no use in waiting by the little door, so she went\r back to the table, half hoping she might find another key on it, or at\r any rate a book of rules for shutting people up like telescopes: this\r time she found a little bottle on it, (“which certainly was not here\r before,” said Alice,) and round the neck of the bottle was a paper\r label, with the words “DRINK ME,” beautifully printed on it in large\r letters.',
#  'It was all very well to say “Drink me,” but the wise little Alice was\r not going to do _that_ in a hurry.',
#  '“No, I’ll look first,” she said,\r “and see whether it’s marked ‘_poison_’ or not”; for she had read\r several nice little histories about children who had got burnt, and\r eaten up by wild beasts and other unpleasant things, all because they\r _would_ not remember the simple rules their friends had taught them:\r such as, that a red-hot poker will burn you if you hold it too long;\r and that if you cut your finger _very_ deeply with a knife, it usually\r bleeds; and she had never forgotten that, if you drink much from a\r bottle marked “poison,” it is almost certain to disagree with you,\r sooner or later.',
#  'However, this bottle was _not_ marked “poison,” so Alice ventured to\r taste it, and finding it very nice, (it had, in fact, a sort of mixed\r flavour of cherry-tart, custard, pine-apple, roast turkey, toffee, and\r hot buttered toast,) she very soon finished it off.',
#  '*      *      *      *      *      *      *\r \r     *      *      *      *      *      *\r \r *      *      *      *      *      *      *\r \r \r “What a curious feeling!” said Alice; “I must be shutting up like a\r telescope.”\r \r And so it was indeed: she was now only ten inches high, and her face\r brightened up at the thought that she was now the right size for going\r through the little door into that lovely garden.',
#  'First, however, she\r waited for a few minutes to see if she was going to shrink any further:\r she felt a little nervous about this; “for it might end, you know,”\r said Alice to herself, “in my going out altogether, like a candle.',
#  'I\r wonder what I should be like then?” And she tried to fancy what the\r flame of a candle is like after the candle is blown out, for she could\r not remember ever having seen such a thing.',
#  'After a while, finding that nothing more happened, she decided on going\r into the garden at once; but, alas for poor Alice!',
#  'when she got to the\r door, she found she had forgotten the little golden key, and when she\r went back to the table for it, she found she could not possibly reach\r it: she could see it quite plainly through the glass, and she tried her\r best to climb up one of the legs of the table, but it was too slippery;\r and when she had tired herself out with trying, the poor little thing\r sat down and cried.',
#  '“Come, there’s no use in crying like that!” said Alice to herself,\r rather sharply; “I advise you to leave off this minute!” She generally\r gave herself very good advice, (though she very seldom followed it),\r and sometimes she scolded herself so severely as to bring tears into\r her eyes; and once she remembered trying to box her own ears for having\r cheated herself in a game of croquet she was playing against herself,\r for this curious child was very fond of pretending to be two people.',
#  '“But it’s no use now,” thought poor Alice, “to pretend to be two\r people!',
#  'Why, there’s hardly enough of me left to make _one_ respectable\r person!”\r \r Soon her eye fell on a little glass box that was lying under the table:\r she opened it, and found in it a very small cake, on which the words\r “EAT ME” were beautifully marked in currants.',
#  '“Well, I’ll eat it,” said\r Alice, “and if it makes me grow larger, I can reach the key; and if it\r makes me grow smaller, I can creep under the door; so either way I’ll\r get into the garden, and I don’t care which happens!”\r \r She ate a little bit, and said anxiously to herself, “Which way?',
#  'Which\r way?”, holding her hand on the top of her head to feel which way it was\r growing, and she was quite surprised to find that she remained the same\r size: to be sure, this generally happens when one eats cake, but Alice\r had got so much into the way of expecting nothing but out-of-the-way\r things to happen, that it seemed quite dull and stupid for life to go\r on in the common way.',
#  'So she set to work, and very soon finished off the cake.',
#  '*      *      *      *      *      *      *\r \r     *      *      *      *      *      *\r \r *      *      *      *      *      *      *\r \r \r \r \r CHAPTER II.',
#  'The Pool of Tears\r \r \r “Curiouser and curiouser!” cried Alice (she was so much surprised, that\r for the moment she quite forgot how to speak good English); “now I’m\r opening out like the largest telescope that ever was!',
#  'Good-bye, feet!”\r (for when she looked down at her feet, they seemed to be almost out of\r sight, they were getting so far off).',
#  '“Oh, my poor little feet, I\r wonder who will put on your shoes and stockings for you now, dears?',
#  'I’m\r sure _I_ shan’t be able!',
#  'I shall be a great deal too far off to trouble\r myself about you: you must manage the best way you can;—but I must be\r kind to them,” thought Alice, “or perhaps they won’t walk the way I\r want to go!',
#  'Let me see: I’ll give them a new pair of boots every\r Christmas.”\r \r And she went on planning to herself how she would manage it.',
#  '“They must\r go by the carrier,” she thought; “and how funny it’ll seem, sending\r presents to one’s own feet!',
#  'And how odd the directions will look!',
#  '_Alice’s Right Foot, Esq., Hearthrug, near the Fender,_ (_with\r      Alice’s love_).',
#  'Oh dear, what nonsense I’m talking!”\r \r Just then her head struck against the roof of the hall: in fact she was\r now more than nine feet high, and she at once took up the little golden\r key and hurried off to the garden door.',
#  'Poor Alice!',
#  'It was as much as she could do, lying down on one side, to\r look through into the garden with one eye; but to get through was more\r hopeless than ever: she sat down and began to cry again.',
#  '“You ought to be ashamed of yourself,” said Alice, “a great girl like\r you,” (she might well say this), “to go on crying in this way!',
#  'Stop\r this moment, I tell you!” But she went on all the same, shedding\r gallons of tears, until there was a large pool all round her, about\r four inches deep and reaching half down the hall.',
#  'After a time she heard a little pattering of feet in the distance, and\r she hastily dried her eyes to see what was coming.',
#  'It was the White\r Rabbit returning, splendidly dressed, with a pair of white kid gloves\r in one hand and a large fan in the other: he came trotting along in a\r great hurry, muttering to himself as he came, “Oh!',
#  'the Duchess, the\r Duchess!',
#  'Oh!',
#  'won’t she be savage if I’ve kept her waiting!” Alice felt\r so desperate that she was ready to ask help of any one; so, when the\r Rabbit came near her, she began, in a low, timid voice, “If you please,\r sir—” The Rabbit started violently, dropped the white kid gloves and\r the fan, and skurried away into the darkness as hard as he could go.',
#  'Alice took up the fan and gloves, and, as the hall was very hot, she\r kept fanning herself all the time she went on talking: “Dear, dear!',
#  'How\r queer everything is to-day!',
#  'And yesterday things went on just as usual.',
#  'I wonder if I’ve been changed in the night?',
#  'Let me think: was I the\r same when I got up this morning?',
#  'I almost think I can remember feeling\r a little different.',
#  'But if I’m not the same, the next question is, Who\r in the world am I?',
#  'Ah, _that’s_ the great puzzle!” And she began\r thinking over all the children she knew that were of the same age as\r herself, to see if she could have been changed for any of them.',
#  '“I’m sure I’m not Ada,” she said, “for her hair goes in such long\r ringlets, and mine doesn’t go in ringlets at all; and I’m sure I can’t\r be Mabel, for I know all sorts of things, and she, oh!',
#  'she knows such a\r very little!',
#  'Besides, _she’s_ she, and _I’m_ I, and—oh dear, how\r puzzling it all is!',
#  'I’ll try if I know all the things I used to know.',
#  'Let me see: four times five is twelve, and four times six is thirteen,\r and four times seven is—oh dear!',
#  'I shall never get to twenty at that\r rate!',
#  'However, the Multiplication Table doesn’t signify: let’s try\r Geography.',
#  'London is the capital of Paris, and Paris is the capital of\r Rome, and Rome—no, _that’s_ all wrong, I’m certain!',
#  'I must have been\r changed for Mabel!',
#  'I’ll try and say ‘_How doth the little_—’” and she\r crossed her hands on her lap as if she were saying lessons, and began\r to repeat it, but her voice sounded hoarse and strange, and the words\r did not come the same as they used to do:—\r \r “How doth the little crocodile\r     Improve his shining tail,\r And pour the waters of the Nile\r     On every golden scale!',
#  '“How cheerfully he seems to grin,\r     How neatly spread his claws,\r And welcome little fishes in\r     With gently smiling jaws!”\r \r \r “I’m sure those are not the right words,” said poor Alice, and her eyes\r filled with tears again as she went on, “I must be Mabel after all, and\r I shall have to go and live in that poky little house, and have next to\r no toys to play with, and oh!',
#  'ever so many lessons to learn!',
#  'No, I’ve\r made up my mind about it; if I’m Mabel, I’ll stay down here!',
#  'It’ll be\r no use their putting their heads down and saying ‘Come up again, dear!’\r I shall only look up and say ‘Who am I then?',
#  'Tell me that first, and\r then, if I like being that person, I’ll come up: if not, I’ll stay down\r here till I’m somebody else’—but, oh dear!” cried Alice, with a sudden\r burst of tears, “I do wish they _would_ put their heads down!',
#  'I am so\r _very_ tired of being all alone here!”\r \r As she said this she looked down at her hands, and was surprised to see\r that she had put on one of the Rabbit’s little white kid gloves while\r she was talking.',
#  '“How _can_ I have done that?” she thought.',
#  '“I must be\r growing small again.” She got up and went to the table to measure\r herself by it, and found that, as nearly as she could guess, she was\r now about two feet high, and was going on shrinking rapidly: she soon\r found out that the cause of this was the fan she was holding, and she\r dropped it hastily, just in time to avoid shrinking away altogether.',
#  '“That _was_ a narrow escape!” said Alice, a good deal frightened at the\r sudden change, but very glad to find herself still in existence; “and\r now for the garden!” and she ran with all speed back to the little\r door: but, alas!',
#  'the little door was shut again, and the little golden\r key was lying on the glass table as before, “and things are worse than\r ever,” thought the poor child, “for I never was so small as this\r before, never!',
#  'And I declare it’s too bad, that it is!”\r \r As she said these words her foot slipped, and in another moment,\r splash!',
#  'she was up to her chin in salt water.',
#  'Her first idea was that\r she had somehow fallen into the sea, “and in that case I can go back by\r railway,” she said to herself.',
#  '(Alice had been to the seaside once in\r her life, and had come to the general conclusion, that wherever you go\r to on the English coast you find a number of bathing machines in the\r sea, some children digging in the sand with wooden spades, then a row\r of lodging houses, and behind them a railway station.)',
#  'However, she\r soon made out that she was in the pool of tears which she had wept when\r she was nine feet high.',
#  '“I wish I hadn’t cried so much!” said Alice, as she swam about, trying\r to find her way out.',
#  '“I shall be punished for it now, I suppose, by\r being drowned in my own tears!',
#  'That _will_ be a queer thing, to be\r sure!',
#  'However, everything is queer to-day.”\r \r Just then she heard something splashing about in the pool a little way\r off, and she swam nearer to make out what it was: at first she thought\r it must be a walrus or hippopotamus, but then she remembered how small\r she was now, and she soon made out that it was only a mouse that had\r slipped in like herself.',
#  '“Would it be of any use, now,” thought Alice, “to speak to this mouse?',
#  'Everything is so out-of-the-way down here, that I should think very\r likely it can talk: at any rate, there’s no harm in trying.” So she\r began: “O Mouse, do you know the way out of this pool?',
#  'I am very tired\r of swimming about here, O Mouse!” (Alice thought this must be the right\r way of speaking to a mouse: she had never done such a thing before, but\r she remembered having seen in her brother’s Latin Grammar, “A mouse—of\r a mouse—to a mouse—a mouse—O mouse!”) The Mouse looked at her rather\r inquisitively, and seemed to her to wink with one of its little eyes,\r but it said nothing.',
#  '“Perhaps it doesn’t understand English,” thought Alice; “I daresay it’s\r a French mouse, come over with William the Conqueror.” (For, with all\r her knowledge of history, Alice had no very clear notion how long ago\r anything had happened.)',
#  'So she began again: “Où est ma chatte?” which\r was the first sentence in her French lesson-book.',
#  'The Mouse gave a\r sudden leap out of the water, and seemed to quiver all over with\r fright.',
#  '“Oh, I beg your pardon!” cried Alice hastily, afraid that she\r had hurt the poor animal’s feelings.',
#  '“I quite forgot you didn’t like\r cats.”\r \r “Not like cats!” cried the Mouse, in a shrill, passionate voice.',
#  '“Would\r _you_ like cats if you were me?”\r \r “Well, perhaps not,” said Alice in a soothing tone: “don’t be angry\r about it.',
#  'And yet I wish I could show you our cat Dinah: I think you’d\r take a fancy to cats if you could only see her.',
#  'She is such a dear\r quiet thing,” Alice went on, half to herself, as she swam lazily about\r in the pool, “and she sits purring so nicely by the fire, licking her\r paws and washing her face—and she is such a nice soft thing to\r nurse—and she’s such a capital one for catching mice—oh, I beg your\r pardon!” cried Alice again, for this time the Mouse was bristling all\r over, and she felt certain it must be really offended.',
#  '“We won’t talk\r about her any more if you’d rather not.”\r \r “We indeed!” cried the Mouse, who was trembling down to the end of his\r tail.',
#  '“As if _I_ would talk on such a subject!',
#  'Our family always\r _hated_ cats: nasty, low, vulgar things!',
#  'Don’t let me hear the name\r again!”\r \r “I won’t indeed!” said Alice, in a great hurry to change the subject of\r conversation.',
#  '“Are you—are you fond—of—of dogs?” The Mouse did not\r answer, so Alice went on eagerly: “There is such a nice little dog near\r our house I should like to show you!',
#  'A little bright-eyed terrier, you\r know, with oh, such long curly brown hair!',
#  'And it’ll fetch things when\r you throw them, and it’ll sit up and beg for its dinner, and all sorts\r of things—I can’t remember half of them—and it belongs to a farmer, you\r know, and he says it’s so useful, it’s worth a hundred pounds!',
#  'He says\r it kills all the rats and—oh dear!” cried Alice in a sorrowful tone,\r “I’m afraid I’ve offended it again!” For the Mouse was swimming away\r from her as hard as it could go, and making quite a commotion in the\r pool as it went.',
#  'So she called softly after it, “Mouse dear!',
#  'Do come back again, and we\r won’t talk about cats or dogs either, if you don’t like them!” When the\r Mouse heard this, it turned round and swam slowly back to her: its face\r was quite pale (with passion, Alice thought), and it said in a low\r trembling voice, “Let us get to the shore, and then I’ll tell you my\r history, and you’ll understand why it is I hate cats and dogs.”\r \r It was high time to go, for the pool was getting quite crowded with the\r birds and animals that had fallen into it: there were a Duck and a\r Dodo, a Lory and an Eaglet, and several other curious creatures.',
#  'Alice\r led the way, and the whole party swam to the shore.',
#  'CHAPTER III.',
#  'A Caucus-Race and a Long Tale\r \r \r They were indeed a queer-looking party that assembled on the bank—the\r birds with draggled feathers, the animals with their fur clinging close\r to them, and all dripping wet, cross, and uncomfortable.',
#  'The first question of course was, how to get dry again: they had a\r consultation about this, and after a few minutes it seemed quite\r natural to Alice to find herself talking familiarly with them, as if\r she had known them all her life.',
#  'Indeed, she had quite a long argument\r with the Lory, who at last turned sulky, and would only say, “I am\r older than you, and must know better;” and this Alice would not allow\r without knowing how old it was, and, as the Lory positively refused to\r tell its age, there was no more to be said.',
#  'At last the Mouse, who seemed to be a person of authority among them,\r called out, “Sit down, all of you, and listen to me!',
#  '_I’ll_ soon make\r you dry enough!” They all sat down at once, in a large ring, with the\r Mouse in the middle.',
#  'Alice kept her eyes anxiously fixed on it, for she\r felt sure she would catch a bad cold if she did not get dry very soon.',
#  '“Ahem!” said the Mouse with an important air, “are you all ready?',
#  'This\r is the driest thing I know.',
#  'Silence all round, if you please!',
#  '‘William\r the Conqueror, whose cause was favoured by the pope, was soon submitted\r to by the English, who wanted leaders, and had been of late much\r accustomed to usurpation and conquest.',
#  'Edwin and Morcar, the earls of\r Mercia and Northumbria—’”\r \r “Ugh!” said the Lory, with a shiver.',
#  '“I beg your pardon!” said the Mouse, frowning, but very politely: “Did\r you speak?”\r \r “Not I!” said the Lory hastily.',
#  '“I thought you did,” said the Mouse.',
#  '“—I proceed.',
#  '‘Edwin and Morcar,\r the earls of Mercia and Northumbria, declared for him: and even\r Stigand, the patriotic archbishop of Canterbury, found it advisable—’”\r \r “Found _what_?” said the Duck.',
#  '“Found _it_,” the Mouse replied rather crossly: “of course you know\r what ‘it’ means.”\r \r “I know what ‘it’ means well enough, when _I_ find a thing,” said the\r Duck: “it’s generally a frog or a worm.',
#  'The question is, what did the\r archbishop find?”\r \r The Mouse did not notice this question, but hurriedly went on, “‘—found\r it advisable to go with Edgar Atheling to meet William and offer him\r the crown.',
#  'William’s conduct at first was moderate.',
#  'But the insolence\r of his Normans—’ How are you getting on now, my dear?” it continued,\r turning to Alice as it spoke.',
#  '“As wet as ever,” said Alice in a melancholy tone: “it doesn’t seem to\r dry me at all.”\r \r “In that case,” said the Dodo solemnly, rising to its feet, “I move\r that the meeting adjourn, for the immediate adoption of more energetic\r remedies—”\r \r “Speak English!” said the Eaglet.',
#  '“I don’t know the meaning of half\r those long words, and, what’s more, I don’t believe you do either!” And\r the Eaglet bent down its head to hide a smile: some of the other birds\r tittered audibly.',
#  '“What I was going to say,” said the Dodo in an offended tone, “was,\r that the best thing to get us dry would be a Caucus-race.”\r \r “What _is_ a Caucus-race?” said Alice; not that she wanted much to\r know, but the Dodo had paused as if it thought that _somebody_ ought to\r speak, and no one else seemed inclined to say anything.',
#  '“Why,” said the Dodo, “the best way to explain it is to do it.” (And,\r as you might like to try the thing yourself, some winter day, I will\r tell you how the Dodo managed it.)',
#  'First it marked out a race-course, in a sort of circle, (“the exact\r shape doesn’t matter,” it said,) and then all the party were placed\r along the course, here and there.',
#  'There was no “One, two, three, and\r away,” but they began running when they liked, and left off when they\r liked, so that it was not easy to know when the race was over.',
#  'However,\r when they had been running half an hour or so, and were quite dry\r again, the Dodo suddenly called out “The race is over!” and they all\r crowded round it, panting, and asking, “But who has won?”\r \r This question the Dodo could not answer without a great deal of\r thought, and it sat for a long time with one finger pressed upon its\r forehead (the position in which you usually see Shakespeare, in the\r pictures of him), while the rest waited in silence.',
#  'At last the Dodo\r said, “_Everybody_ has won, and all must have prizes.”\r \r “But who is to give the prizes?” quite a chorus of voices asked.',
#  '“Why, _she_, of course,” said the Dodo, pointing to Alice with one\r finger; and the whole party at once crowded round her, calling out in a\r confused way, “Prizes!',
#  'Prizes!”\r \r Alice had no idea what to do, and in despair she put her hand in her\r pocket, and pulled out a box of comfits, (luckily the salt water had\r not got into it), and handed them round as prizes.',
#  'There was exactly\r one a-piece, all round.',
#  '“But she must have a prize herself, you know,” said the Mouse.',
#  '“Of course,” the Dodo replied very gravely.',
#  '“What else have you got in\r your pocket?” he went on, turning to Alice.',
#  '“Only a thimble,” said Alice sadly.',
#  '“Hand it over here,” said the Dodo.',
#  'Then they all crowded round her once more, while the Dodo solemnly\r presented the thimble, saying “We beg your acceptance of this elegant\r thimble;” and, when it had finished this short speech, they all\r cheered.',
#  'Alice thought the whole thing very absurd, but they all looked so grave\r that she did not dare to laugh; and, as she could not think of anything\r to say, she simply bowed, and took the thimble, looking as solemn as\r she could.',
#  'The next thing was to eat the comfits: this caused some noise and\r confusion, as the large birds complained that they could not taste\r theirs, and the small ones choked and had to be patted on the back.',
#  'However, it was over at last, and they sat down again in a ring, and\r begged the Mouse to tell them something more.',
#  '“You promised to tell me your history, you know,” said Alice, “and why\r it is you hate—C and D,” she added in a whisper, half afraid that it\r would be offended again.',
#  '“Mine is a long and a sad tale!” said the Mouse, turning to Alice, and\r sighing.',
#  '“It _is_ a long tail, certainly,” said Alice, looking down with wonder\r at the Mouse’s tail; “but why do you call it sad?” And she kept on\r puzzling about it while the Mouse was speaking, so that her idea of the\r tale was something like this:—\r \r          “Fury said to a mouse, That he met in the house, ‘Let us both\r          go to law: _I_ will prosecute _you_.—Come, I’ll take no\r          denial; We must have a trial: For really this morning I’ve\r          nothing to do.’ Said the mouse to the cur, ‘Such a trial, dear\r          sir, With no jury or judge, would be wasting our breath.’\r          ‘I’ll be judge, I’ll be jury,’ Said cunning old Fury: ‘I’ll\r          try the whole cause, and condemn you to death.’”\r \r “You are not attending!” said the Mouse to Alice severely.',
#  '“What are\r you thinking of?”\r \r “I beg your pardon,” said Alice very humbly: “you had got to the fifth\r bend, I think?”\r \r “I had _not!_” cried the Mouse, sharply and very angrily.',
#  '“A knot!” said Alice, always ready to make herself useful, and looking\r anxiously about her.',
#  '“Oh, do let me help to undo it!”\r \r “I shall do nothing of the sort,” said the Mouse, getting up and\r walking away.',
#  '“You insult me by talking such nonsense!”\r \r “I didn’t mean it!” pleaded poor Alice.',
#  '“But you’re so easily offended,\r you know!”\r \r The Mouse only growled in reply.',
#  '“Please come back and finish your story!” Alice called after it; and\r the others all joined in chorus, “Yes, please do!” but the Mouse only\r shook its head impatiently, and walked a little quicker.',
#  '“What a pity it wouldn’t stay!” sighed the Lory, as soon as it was\r quite out of sight; and an old Crab took the opportunity of saying to\r her daughter “Ah, my dear!',
#  'Let this be a lesson to you never to lose\r _your_ temper!” “Hold your tongue, Ma!” said the young Crab, a little\r snappishly.',
#  '“You’re enough to try the patience of an oyster!”\r \r “I wish I had our Dinah here, I know I do!” said Alice aloud,\r addressing nobody in particular.',
#  '“She’d soon fetch it back!”\r \r “And who is Dinah, if I might venture to ask the question?” said the\r Lory.',
#  'Alice replied eagerly, for she was always ready to talk about her pet:\r “Dinah’s our cat.',
#  'And she’s such a capital one for catching mice you\r can’t think!',
#  'And oh, I wish you could see her after the birds!',
#  'Why,\r she’ll eat a little bird as soon as look at it!”\r \r This speech caused a remarkable sensation among the party.',
#  'Some of the\r birds hurried off at once: one old Magpie began wrapping itself up very\r carefully, remarking, “I really must be getting home; the night-air\r doesn’t suit my throat!” and a Canary called out in a trembling voice\r to its children, “Come away, my dears!',
#  'It’s high time you were all in\r bed!” On various pretexts they all moved off, and Alice was soon left\r alone.',
#  '“I wish I hadn’t mentioned Dinah!” she said to herself in a melancholy\r tone.',
#  '“Nobody seems to like her, down here, and I’m sure she’s the best\r cat in the world!',
#  'Oh, my dear Dinah!',
#  'I wonder if I shall ever see you\r any more!” And here poor Alice began to cry again, for she felt very\r lonely and low-spirited.',
#  'In a little while, however, she again heard a\r little pattering of footsteps in the distance, and she looked up\r eagerly, half hoping that the Mouse had changed his mind, and was\r coming back to finish his story.',
#  'CHAPTER IV.',
#  'The Rabbit Sends in a Little Bill\r \r \r It was the White Rabbit, trotting slowly back again, and looking\r anxiously about as it went, as if it had lost something; and she heard\r it muttering to itself “The Duchess!',
#  'The Duchess!',
#  'Oh my dear paws!',
#  'Oh\r my fur and whiskers!',
#  'She’ll get me executed, as sure as ferrets are\r ferrets!',
#  'Where _can_ I have dropped them, I wonder?” Alice guessed in a\r moment that it was looking for the fan and the pair of white kid\r gloves, and she very good-naturedly began hunting about for them, but\r they were nowhere to be seen—everything seemed to have changed since\r her swim in the pool, and the great hall, with the glass table and the\r little door, had vanished completely.',
#  'Very soon the Rabbit noticed Alice, as she went hunting about, and\r called out to her in an angry tone, “Why, Mary Ann, what _are_ you\r doing out here?',
#  'Run home this moment, and fetch me a pair of gloves and\r a fan!',
#  'Quick, now!” And Alice was so much frightened that she ran off\r at once in the direction it pointed to, without trying to explain the\r mistake it had made.',
#  '“He took me for his housemaid,” she said to herself as she ran.',
#  '“How\r surprised he’ll be when he finds out who I am!',
#  'But I’d better take him\r his fan and gloves—that is, if I can find them.” As she said this, she\r came upon a neat little house, on the door of which was a bright brass\r plate with the name “W.',
#  'RABBIT,” engraved upon it.',
#  'She went in without\r knocking, and hurried upstairs, in great fear lest she should meet the\r real Mary Ann, and be turned out of the house before she had found the\r fan and gloves.',
#  '“How queer it seems,” Alice said to herself, “to be going messages for\r a rabbit!',
#  'I suppose Dinah’ll be sending me on messages next!” And she\r began fancying the sort of thing that would happen: “‘Miss Alice!',
#  'Come\r here directly, and get ready for your walk!’ ‘Coming in a minute,\r nurse!',
#  'But I’ve got to see that the mouse doesn’t get out.’ Only I\r don’t think,” Alice went on, “that they’d let Dinah stop in the house\r if it began ordering people about like that!”\r \r By this time she had found her way into a tidy little room with a table\r in the window, and on it (as she had hoped) a fan and two or three\r pairs of tiny white kid gloves: she took up the fan and a pair of the\r gloves, and was just going to leave the room, when her eye fell upon a\r little bottle that stood near the looking-glass.',
#  'There was no label\r this time with the words “DRINK ME,” but nevertheless she uncorked it\r and put it to her lips.',
#  '“I know _something_ interesting is sure to\r happen,” she said to herself, “whenever I eat or drink anything; so\r I’ll just see what this bottle does.',
#  'I do hope it’ll make me grow large\r again, for really I’m quite tired of being such a tiny little thing!”\r \r It did so indeed, and much sooner than she had expected: before she had\r drunk half the bottle, she found her head pressing against the ceiling,\r and had to stoop to save her neck from being broken.',
#  'She hastily put\r down the bottle, saying to herself “That’s quite enough—I hope I shan’t\r grow any more—As it is, I can’t get out at the door—I do wish I hadn’t\r drunk quite so much!”\r \r Alas!',
#  'it was too late to wish that!',
#  'She went on growing, and growing,\r and very soon had to kneel down on the floor: in another minute there\r was not even room for this, and she tried the effect of lying down with\r one elbow against the door, and the other arm curled round her head.',
#  'Still she went on growing, and, as a last resource, she put one arm out\r of the window, and one foot up the chimney, and said to herself “Now I\r can do no more, whatever happens.',
#  'What _will_ become of me?”\r \r Luckily for Alice, the little magic bottle had now had its full effect,\r and she grew no larger: still it was very uncomfortable, and, as there\r seemed to be no sort of chance of her ever getting out of the room\r again, no wonder she felt unhappy.',
#  '“It was much pleasanter at home,” thought poor Alice, “when one wasn’t\r always growing larger and smaller, and being ordered about by mice and\r rabbits.',
#  'I almost wish I hadn’t gone down that rabbit-hole—and yet—and\r yet—it’s rather curious, you know, this sort of life!',
#  'I do wonder what\r _can_ have happened to me!',
#  'When I used to read fairy-tales, I fancied\r that kind of thing never happened, and now here I am in the middle of\r one!',
#  'There ought to be a book written about me, that there ought!',
#  'And\r when I grow up, I’ll write one—but I’m grown up now,” she added in a\r sorrowful tone; “at least there’s no room to grow up any more _here_.”\r \r “But then,” thought Alice, “shall I _never_ get any older than I am\r now?',
#  'That’ll be a comfort, one way—never to be an old woman—but\r then—always to have lessons to learn!',
#  'Oh, I shouldn’t like _that!_”\r \r “Oh, you foolish Alice!” she answered herself.',
#  '“How can you learn\r lessons in here?',
#  'Why, there’s hardly room for _you_, and no room at all\r for any lesson-books!”\r \r And so she went on, taking first one side and then the other, and\r making quite a conversation of it altogether; but after a few minutes\r she heard a voice outside, and stopped to listen.',
#  '“Mary Ann!',
#  'Mary Ann!” said the voice.',
#  '“Fetch me my gloves this moment!”\r Then came a little pattering of feet on the stairs.',
#  'Alice knew it was\r the Rabbit coming to look for her, and she trembled till she shook the\r house, quite forgetting that she was now about a thousand times as\r large as the Rabbit, and had no reason to be afraid of it.',
#  'Presently the Rabbit came up to the door, and tried to open it; but, as\r the door opened inwards, and Alice’s elbow was pressed hard against it,\r that attempt proved a failure.',
#  'Alice heard it say to itself “Then I’ll\r go round and get in at the window.”\r \r “_That_ you won’t!” thought Alice, and, after waiting till she fancied\r she heard the Rabbit just under the window, she suddenly spread out her\r hand, and made a snatch in the air.',
#  'She did not get hold of anything,\r but she heard a little shriek and a fall, and a crash of broken glass,\r from which she concluded that it was just possible it had fallen into a\r cucumber-frame, or something of the sort.',
#  'Next came an angry voice—the Rabbit’s—“Pat!',
#  'Pat!',
#  'Where are you?” And\r then a voice she had never heard before, “Sure then I’m here!',
#  'Digging\r for apples, yer honour!”\r \r “Digging for apples, indeed!” said the Rabbit angrily.',
#  '“Here!',
#  'Come and\r help me out of _this!_” (Sounds of more broken glass.)',
#  '“Now tell me, Pat, what’s that in the window?”\r \r “Sure, it’s an arm, yer honour!” (He pronounced it “arrum.”)\r \r “An arm, you goose!',
#  'Who ever saw one that size?',
#  'Why, it fills the whole\r window!”\r \r “Sure, it does, yer honour: but it’s an arm for all that.”\r \r “Well, it’s got no business there, at any rate: go and take it away!”\r \r There was a long silence after this, and Alice could only hear whispers\r now and then; such as, “Sure, I don’t like it, yer honour, at all, at\r all!” “Do as I tell you, you coward!” and at last she spread out her\r hand again, and made another snatch in the air.',
#  'This time there were\r _two_ little shrieks, and more sounds of broken glass.',
#  '“What a number\r of cucumber-frames there must be!” thought Alice.',
#  '“I wonder what\r they’ll do next!',
#  'As for pulling me out of the window, I only wish they\r _could!_ I’m sure _I_ don’t want to stay in here any longer!”\r \r She waited for some time without hearing anything more: at last came a\r rumbling of little cartwheels, and the sound of a good many voices all\r talking together: she made out the words: “Where’s the other\r ladder?—Why, I hadn’t to bring but one; Bill’s got the other—Bill!',
#  'fetch it here, lad!—Here, put ’em up at this corner—No, tie ’em\r together first—they don’t reach half high enough yet—Oh!',
#  'they’ll do\r well enough; don’t be particular—Here, Bill!',
#  'catch hold of this\r rope—Will the roof bear?—Mind that loose slate—Oh, it’s coming down!',
#  'Heads below!” (a loud crash)—“Now, who did that?—It was Bill, I\r fancy—Who’s to go down the chimney?—Nay, _I_ shan’t!',
#  '_You_ do\r it!—_That_ I won’t, then!—Bill’s to go down—Here, Bill!',
#  'the master says\r you’re to go down the chimney!”\r \r “Oh!',
#  'So Bill’s got to come down the chimney, has he?” said Alice to\r herself.',
#  '“Shy, they seem to put everything upon Bill!',
#  'I wouldn’t be in\r Bill’s place for a good deal: this fireplace is narrow, to be sure; but\r I _think_ I can kick a little!”\r \r She drew her foot as far down the chimney as she could, and waited till\r she heard a little animal (she couldn’t guess of what sort it was)\r scratching and scrambling about in the chimney close above her: then,\r saying to herself “This is Bill,” she gave one sharp kick, and waited\r to see what would happen next.',
#  'The first thing she heard was a general chorus of “There goes Bill!”\r then the Rabbit’s voice along—“Catch him, you by the hedge!” then\r silence, and then another confusion of voices—“Hold up his head—Brandy\r now—Don’t choke him—How was it, old fellow?',
#  'What happened to you?',
#  'Tell\r us all about it!”\r \r Last came a little feeble, squeaking voice, (“That’s Bill,” thought\r Alice,) “Well, I hardly know—No more, thank ye; I’m better now—but I’m\r a deal too flustered to tell you—all I know is, something comes at me\r like a Jack-in-the-box, and up I goes like a sky-rocket!”\r \r “So you did, old fellow!” said the others.',
#  '“We must burn the house down!” said the Rabbit’s voice; and Alice\r called out as loud as she could, “If you do, I’ll set Dinah at you!”\r \r There was a dead silence instantly, and Alice thought to herself, “I\r wonder what they _will_ do next!',
#  'If they had any sense, they’d take the\r roof off.” After a minute or two, they began moving about again, and\r Alice heard the Rabbit say, “A barrowful will do, to begin with.”\r \r “A barrowful of _what?_” thought Alice; but she had not long to doubt,\r for the next moment a shower of little pebbles came rattling in at the\r window, and some of them hit her in the face.',
#  '“I’ll put a stop to\r this,” she said to herself, and shouted out, “You’d better not do that\r again!” which produced another dead silence.',
#  'Alice noticed with some surprise that the pebbles were all turning into\r little cakes as they lay on the floor, and a bright idea came into her\r head.',
#  '“If I eat one of these cakes,” she thought, “it’s sure to make\r _some_ change in my size; and as it can’t possibly make me larger, it\r must make me smaller, I suppose.”\r \r So she swallowed one of the cakes, and was delighted to find that she\r began shrinking directly.',
#  'As soon as she was small enough to get\r through the door, she ran out of the house, and found quite a crowd of\r little animals and birds waiting outside.',
#  'The poor little Lizard, Bill,\r was in the middle, being held up by two guinea-pigs, who were giving it\r something out of a bottle.',
#  'They all made a rush at Alice the moment she\r appeared; but she ran off as hard as she could, and soon found herself\r safe in a thick wood.',
#  '“The first thing I’ve got to do,” said Alice to herself, as she\r wandered about in the wood, “is to grow to my right size again; and the\r second thing is to find my way into that lovely garden.',
#  'I think that\r will be the best plan.”\r \r It sounded an excellent plan, no doubt, and very neatly and simply\r arranged; the only difficulty was, that she had not the smallest idea\r how to set about it; and while she was peering about anxiously among\r the trees, a little sharp bark just over her head made her look up in a\r great hurry.',
#  'An enormous puppy was looking down at her with large round eyes, and\r feebly stretching out one paw, trying to touch her.',
#  '“Poor little\r thing!” said Alice, in a coaxing tone, and she tried hard to whistle to\r it; but she was terribly frightened all the time at the thought that it\r might be hungry, in which case it would be very likely to eat her up in\r spite of all her coaxing.',
#  'Hardly knowing what she did, she picked up a little bit of stick, and\r held it out to the puppy; whereupon the puppy jumped into the air off\r all its feet at once, with a yelp of delight, and rushed at the stick,\r and made believe to worry it; then Alice dodged behind a great thistle,\r to keep herself from being run over; and the moment she appeared on the\r other side, the puppy made another rush at the stick, and tumbled head\r over heels in its hurry to get hold of it; then Alice, thinking it was\r very like having a game of play with a cart-horse, and expecting every\r moment to be trampled under its feet, ran round the thistle again; then\r the puppy began a series of short charges at the stick, running a very\r little way forwards each time and a long way back, and barking hoarsely\r all the while, till at last it sat down a good way off, panting, with\r its tongue hanging out of its mouth, and its great eyes half shut.',
#  'This seemed to Alice a good opportunity for making her escape; so she\r set off at once, and ran till she was quite tired and out of breath,\r and till the puppy’s bark sounded quite faint in the distance.',
#  '“And yet what a dear little puppy it was!” said Alice, as she leant\r against a buttercup to rest herself, and fanned herself with one of the\r leaves: “I should have liked teaching it tricks very much, if—if I’d\r only been the right size to do it!',
#  'Oh dear!',
# ...
#  '“After that,” continued the Hatter, “I cut some more bread-and-butter—”\r \r “But what did the Dormouse say?” one of the jury asked.',
#  '“That I can’t remember,” said the Hatter.',
#  '“You _must_ remember,” remarked the King, “or I’ll have you executed.”\r \r The miserable Hatter dropped his teacup and bread-and-butter, and went\r down on one knee.',
#  '“I’m a poor man, your Majesty,” he began.',
#  '“You’re a _very_ poor _speaker_,” said the King.',
#  'Here one of the guinea-pigs cheered, and was immediately suppressed by\r the officers of the court.',
#  '(As that is rather a hard word, I will just\r explain to you how it was done.',
#  'They had a large canvas bag, which tied\r up at the mouth with strings: into this they slipped the guinea-pig,\r head first, and then sat upon it.)',
#  '“I’m glad I’ve seen that done,” thought Alice.',
#  '“I’ve so often read in\r the newspapers, at the end of trials, “There was some attempts at\r applause, which was immediately suppressed by the officers of the\r court,” and I never understood what it meant till now.”\r \r “If that’s all you know about it, you may stand down,” continued the\r King.',
#  '“I can’t go no lower,” said the Hatter: “I’m on the floor, as it is.”\r \r “Then you may _sit_ down,” the King replied.',
#  'Here the other guinea-pig cheered, and was suppressed.',
#  '“Come, that finished the guinea-pigs!” thought Alice.',
#  '“Now we shall get\r on better.”\r \r “I’d rather finish my tea,” said the Hatter, with an anxious look at\r the Queen, who was reading the list of singers.',
#  '“You may go,” said the King, and the Hatter hurriedly left the court,\r without even waiting to put his shoes on.',
#  '“—and just take his head off outside,” the Queen added to one of the\r officers: but the Hatter was out of sight before the officer could get\r to the door.',
#  '“Call the next witness!” said the King.',
#  'The next witness was the Duchess’s cook.',
#  'She carried the pepper-box in\r her hand, and Alice guessed who it was, even before she got into the\r court, by the way the people near the door began sneezing all at once.',
#  '“Give your evidence,” said the King.',
#  '“Shan’t,” said the cook.',
#  'The King looked anxiously at the White Rabbit, who said in a low voice,\r “Your Majesty must cross-examine _this_ witness.”\r \r “Well, if I must, I must,” the King said, with a melancholy air, and,\r after folding his arms and frowning at the cook till his eyes were\r nearly out of sight, he said in a deep voice, “What are tarts made of?”\r \r “Pepper, mostly,” said the cook.',
#  '“Treacle,” said a sleepy voice behind her.',
#  '“Collar that Dormouse,” the Queen shrieked out.',
#  '“Behead that Dormouse!',
#  'Turn that Dormouse out of court!',
#  'Suppress him!',
#  'Pinch him!',
#  'Off with his\r whiskers!”\r \r For some minutes the whole court was in confusion, getting the Dormouse\r turned out, and, by the time they had settled down again, the cook had\r disappeared.',
#  '“Never mind!” said the King, with an air of great relief.',
#  '“Call the\r next witness.” And he added in an undertone to the Queen, “Really, my\r dear, _you_ must cross-examine the next witness.',
#  'It quite makes my\r forehead ache!”\r \r Alice watched the White Rabbit as he fumbled over the list, feeling\r very curious to see what the next witness would be like, “—for they\r haven’t got much evidence _yet_,” she said to herself.',
#  'Imagine her\r surprise, when the White Rabbit read out, at the top of his shrill\r little voice, the name “Alice!”\r \r \r \r \r CHAPTER XII.',
#  'Alice’s Evidence\r \r \r “Here!” cried Alice, quite forgetting in the flurry of the moment how\r large she had grown in the last few minutes, and she jumped up in such\r a hurry that she tipped over the jury-box with the edge of her skirt,\r upsetting all the jurymen on to the heads of the crowd below, and there\r they lay sprawling about, reminding her very much of a globe of\r goldfish she had accidentally upset the week before.',
#  '“Oh, I _beg_ your pardon!” she exclaimed in a tone of great dismay, and\r began picking them up again as quickly as she could, for the accident\r of the goldfish kept running in her head, and she had a vague sort of\r idea that they must be collected at once and put back into the\r jury-box, or they would die.',
#  '“The trial cannot proceed,” said the King in a very grave voice, “until\r all the jurymen are back in their proper places—_all_,” he repeated\r with great emphasis, looking hard at Alice as he said so.',
#  'Alice looked at the jury-box, and saw that, in her haste, she had put\r the Lizard in head downwards, and the poor little thing was waving its\r tail about in a melancholy way, being quite unable to move.',
#  'She soon\r got it out again, and put it right; “not that it signifies much,” she\r said to herself; “I should think it would be _quite_ as much use in the\r trial one way up as the other.”\r \r As soon as the jury had a little recovered from the shock of being\r upset, and their slates and pencils had been found and handed back to\r them, they set to work very diligently to write out a history of the\r accident, all except the Lizard, who seemed too much overcome to do\r anything but sit with its mouth open, gazing up into the roof of the\r court.',
#  '“What do you know about this business?” the King said to Alice.',
#  '“Nothing,” said Alice.',
#  '“Nothing _whatever?_” persisted the King.',
#  '“Nothing whatever,” said Alice.',
#  '“That’s very important,” the King said, turning to the jury.',
#  'They were\r just beginning to write this down on their slates, when the White\r Rabbit interrupted: “_Un_important, your Majesty means, of course,” he\r said in a very respectful tone, but frowning and making faces at him as\r he spoke.',
#  '“_Un_important, of course, I meant,” the King hastily said, and went on\r to himself in an undertone,\r \r “important—unimportant—unimportant—important—” as if he were trying\r which word sounded best.',
#  'Some of the jury wrote it down “important,” and some “unimportant.”\r Alice could see this, as she was near enough to look over their slates;\r “but it doesn’t matter a bit,” she thought to herself.',
#  'At this moment the King, who had been for some time busily writing in\r his note-book, cackled out “Silence!” and read out from his book, “Rule\r Forty-two.',
#  '_All persons more than a mile high to leave the court_.”\r \r Everybody looked at Alice.',
#  '“_I’m_ not a mile high,” said Alice.',
#  '“You are,” said the King.',
#  '“Nearly two miles high,” added the Queen.',
#  '“Well, I shan’t go, at any rate,” said Alice: “besides, that’s not a\r regular rule: you invented it just now.”\r \r “It’s the oldest rule in the book,” said the King.',
#  '“Then it ought to be Number One,” said Alice.',
#  'The King turned pale, and shut his note-book hastily.',
#  '“Consider your\r verdict,” he said to the jury, in a low, trembling voice.',
#  '“There’s more evidence to come yet, please your Majesty,” said the\r White Rabbit, jumping up in a great hurry; “this paper has just been\r picked up.”\r \r “What’s in it?” said the Queen.',
#  '“I haven’t opened it yet,” said the White Rabbit, “but it seems to be a\r letter, written by the prisoner to—to somebody.”\r \r “It must have been that,” said the King, “unless it was written to\r nobody, which isn’t usual, you know.”\r \r “Who is it directed to?” said one of the jurymen.',
#  '“It isn’t directed at all,” said the White Rabbit; “in fact, there’s\r nothing written on the _outside_.” He unfolded the paper as he spoke,\r and added “It isn’t a letter, after all: it’s a set of verses.”\r \r “Are they in the prisoner’s handwriting?” asked another of the jurymen.',
#  '“No, they’re not,” said the White Rabbit, “and that’s the queerest\r thing about it.” (The jury all looked puzzled.)',
#  '“He must have imitated somebody else’s hand,” said the King.',
#  '(The jury\r all brightened up again.)',
#  '“Please your Majesty,” said the Knave, “I didn’t write it, and they\r can’t prove I did: there’s no name signed at the end.”\r \r “If you didn’t sign it,” said the King, “that only makes the matter\r worse.',
#  'You _must_ have meant some mischief, or else you’d have signed\r your name like an honest man.”\r \r There was a general clapping of hands at this: it was the first really\r clever thing the King had said that day.',
#  '“That _proves_ his guilt,” said the Queen.',
#  '“It proves nothing of the sort!” said Alice.',
#  '“Why, you don’t even know\r what they’re about!”\r \r “Read them,” said the King.',
#  'The White Rabbit put on his spectacles.',
#  '“Where shall I begin, please\r your Majesty?” he asked.',
#  '“Begin at the beginning,” the King said gravely, “and go on till you\r come to the end: then stop.”\r \r These were the verses the White Rabbit read:—\r \r “They told me you had been to her,\r     And mentioned me to him:\r She gave me a good character,\r     But said I could not swim.',
#  'He sent them word I had not gone\r     (We know it to be true):\r If she should push the matter on,\r     What would become of you?',
#  'I gave her one, they gave him two,\r     You gave us three or more;\r They all returned from him to you,\r     Though they were mine before.',
#  'If I or she should chance to be\r     Involved in this affair,\r He trusts to you to set them free,\r     Exactly as we were.',
#  'My notion was that you had been\r     (Before she had this fit)\r An obstacle that came between\r     Him, and ourselves, and it.',
#  'Don’t let him know she liked them best,\r     For this must ever be\r A secret, kept from all the rest,\r     Between yourself and me.”\r \r \r “That’s the most important piece of evidence we’ve heard yet,” said the\r King, rubbing his hands; “so now let the jury—”\r \r “If any one of them can explain it,” said Alice, (she had grown so\r large in the last few minutes that she wasn’t a bit afraid of\r interrupting him,) “I’ll give him sixpence.',
#  '_I_ don’t believe there’s\r an atom of meaning in it.”\r \r The jury all wrote down on their slates, “_She_ doesn’t believe there’s\r an atom of meaning in it,” but none of them attempted to explain the\r paper.',
#  '“If there’s no meaning in it,” said the King, “that saves a world of\r trouble, you know, as we needn’t try to find any.',
#  'And yet I don’t\r know,” he went on, spreading out the verses on his knee, and looking at\r them with one eye; “I seem to see some meaning in them, after all.',
#  '“—_said I could not swim_—” you can’t swim, can you?” he added, turning\r to the Knave.',
#  'The Knave shook his head sadly.',
#  '“Do I look like it?” he said.',
#  '(Which he\r certainly did _not_, being made entirely of cardboard.)',
#  '“All right, so far,” said the King, and he went on muttering over the\r verses to himself: “‘_We know it to be true_—’ that’s the jury, of\r course—‘_I gave her one, they gave him two_—’ why, that must be what he\r did with the tarts, you know—”\r \r “But, it goes on ‘_they all returned from him to you_,’” said Alice.',
#  '“Why, there they are!” said the King triumphantly, pointing to the\r tarts on the table.',
#  '“Nothing can be clearer than _that_.',
#  'Then\r again—‘_before she had this fit_—’ you never had fits, my dear, I\r think?” he said to the Queen.',
#  '“Never!” said the Queen furiously, throwing an inkstand at the Lizard\r as she spoke.',
#  '(The unfortunate little Bill had left off writing on his\r slate with one finger, as he found it made no mark; but he now hastily\r began again, using the ink, that was trickling down his face, as long\r as it lasted.)',
#  '“Then the words don’t _fit_ you,” said the King, looking round the\r court with a smile.',
#  'There was a dead silence.',
#  '“It’s a pun!” the King added in an offended tone, and everybody\r laughed, “Let the jury consider their verdict,” the King said, for\r about the twentieth time that day.',
#  '“No, no!” said the Queen.',
#  '“Sentence first—verdict afterwards.”\r \r “Stuff and nonsense!” said Alice loudly.',
#  '“The idea of having the\r sentence first!”\r \r “Hold your tongue!” said the Queen, turning purple.',
#  '“I won’t!” said Alice.',
#  '“Off with her head!” the Queen shouted at the top of her voice.',
#  'Nobody\r moved.',
#  '“Who cares for you?” said Alice, (she had grown to her full size by\r this time.)',
#  '“You’re nothing but a pack of cards!”\r \r At this the whole pack rose up into the air, and came flying down upon\r her: she gave a little scream, half of fright and half of anger, and\r tried to beat them off, and found herself lying on the bank, with her\r head in the lap of her sister, who was gently brushing away some dead\r leaves that had fluttered down from the trees upon her face.',
#  '“Wake up, Alice dear!” said her sister; “Why, what a long sleep you’ve\r had!”\r \r “Oh, I’ve had such a curious dream!” said Alice, and she told her\r sister, as well as she could remember them, all these strange\r Adventures of hers that you have just been reading about; and when she\r had finished, her sister kissed her, and said, “It _was_ a curious\r dream, dear, certainly: but now run in to your tea; it’s getting late.”\r So Alice got up and ran off, thinking while she ran, as well she might,\r what a wonderful dream it had been.',
#  'But her sister sat still just as she left her, leaning her head on her\r hand, watching the setting sun, and thinking of little Alice and all\r her wonderful Adventures, till she too began dreaming after a fashion,\r and this was her dream:—\r \r First, she dreamed of little Alice herself, and once again the tiny\r hands were clasped upon her knee, and the bright eager eyes were\r looking up into hers—she could hear the very tones of her voice, and\r see that queer little toss of her head to keep back the wandering hair\r that _would_ always get into her eyes—and still as she listened, or\r seemed to listen, the whole place around her became alive with the\r strange creatures of her little sister’s dream.',
#  'The long grass rustled at her feet as the White Rabbit hurried by—the\r frightened Mouse splashed his way through the neighbouring pool—she\r could hear the rattle of the teacups as the March Hare and his friends\r shared their never-ending meal, and the shrill voice of the Queen\r ordering off her unfortunate guests to execution—once more the pig-baby\r was sneezing on the Duchess’s knee, while plates and dishes crashed\r around it—once more the shriek of the Gryphon, the squeaking of the\r Lizard’s slate-pencil, and the choking of the suppressed guinea-pigs,\r filled the air, mixed up with the distant sobs of the miserable Mock\r Turtle.',
#  'So she sat on, with closed eyes, and half believed herself in\r Wonderland, though she knew she had but to open them again, and all\r would change to dull reality—the grass would be only rustling in the\r wind, and the pool rippling to the waving of the reeds—the rattling\r teacups would change to tinkling sheep-bells, and the Queen’s shrill\r cries to the voice of the shepherd boy—and the sneeze of the baby, the\r shriek of the Gryphon, and all the other queer noises, would change\r (she knew) to the confused clamour of the busy farm-yard—while the\r lowing of the cattle in the distance would take the place of the Mock\r Turtle’s heavy sobs.',
#  'Lastly, she pictured to herself how this same little sister of hers\r would, in the after-time, be herself a grown woman; and how she would\r keep, through all her riper years, the simple and loving heart of her\r childhood: and how she would gather about her other little children,\r and make _their_ eyes bright and eager with many a strange tale,\r perhaps even with the dream of Wonderland of long ago: and how she\r would feel with all their simple sorrows, and find a pleasure in all\r their simple joys, remembering her own child-life, and the happy summer\r days.',
#  'THE END\r \r *** END OF THE PROJECT GUTENBERG EBOOK 11 ***']

# %%
data = []

for i in sent_tokenize(cleaned_text):
    temp = []
    # tokenize the sentence into words
    for j in word_tokenize(i):
        temp.append(j.lower())
    data.append(temp)

# %%
model1 = gensim.models.Word2Vec(data, min_count=1, vector_size=100, window=5)

model2 = gensim.models.Word2Vec(data, min_count=1, vector_size=100, window=5, sg=1)

# %%
print("Cosine similarity between 'alice' " +
      "and 'wonderland' - CBOW : ",
      model1.wv.similarity('alice', 'wonderland'))

print("Cosine similarity between 'alice' " +
      "and 'machines' - CBOW : ",
      model1.wv.similarity('alice', 'machines'))
# Out:
# Cosine similarity between 'alice' and 'wonderland' - CBOW :  0.9913404
# Cosine similarity between 'alice' and 'machines' - CBOW :  0.9400847
